# %%
import pandas as pd
import numpy as np

# %%
DATA_URL = ("Motor_Vehicle_Collisions_-_Crashes.csv")

data = pd.read_csv(DATA_URL, nrows=100, parse_dates=[['CRASH_DATE', 'CRASH_TIME']])
data.dropna(subset=['LATITUDE', 'LONGITUDE'], inplace=True)
data.head()
# Out:
#    CRASH_DATE_CRASH_TIME    BOROUGH  ZIP_CODE   LATITUDE  LONGITUDE  \
# 10   2014-02-03 20:30:00        NaN       NaN  40.734926 -73.923111
# 17   2016-06-12 00:00:00  MANHATTAN   10027.0  40.807770 -73.945490
# 23   2018-08-01 05:15:00        NaN       NaN  40.895195 -73.880120
# 31   2018-07-31 13:12:00        NaN       NaN  40.833736 -73.888810
# 42   2020-04-04 22:52:00   BROOKLYN   11207.0  40.669190 -73.885700
#
#                           LOCATION                    ON_STREET_NAME  \
# 10  POINT (-73.9231109 40.7349257)                               NaN
# 17      POINT (-73.94549 40.80777)  WEST 125 STREET
# 23     POINT (-73.88012 40.895195)  JEROME AVENUE
# 31     POINT (-73.88881 40.833736)  HOE AVENUE
# 42       POINT (-73.8857 40.66919)  BLAKE AVENUE
#
#    CROSS_STREET_NAME OFF_STREET_NAME  INJURED_PERSONS  ...  \
# 10               NaN             NaN                0  ...
# 17      LENOX AVENUE             NaN                1  ...
# 23               NaN             NaN                1  ...
# 31               NaN             NaN                0  ...
# 42     JEROME STREET             NaN                0  ...
#
#     CONTRIBUTING_FACTOR_VEHICLE_2  CONTRIBUTING_FACTOR_VEHICLE_3  \
# 10                            NaN                            NaN
# 17                            NaN                            NaN
# 23                            NaN                            NaN
# 31                            NaN                            NaN
# 42                    Unspecified                            NaN
#
#     CONTRIBUTING_FACTOR_VEHICLE_4  CONTRIBUTING_FACTOR_VEHICLE_5  \
# 10                            NaN                            NaN
# 17                            NaN                            NaN
# 23                            NaN                            NaN
# 31                            NaN                            NaN
# 42                            NaN                            NaN
#
#     COLLISION_ID     VEHICLE_TYPE_1  VEHICLE_TYPE_2 VEHICLE_TYPE_3  \
# 10       3046267  PASSENGER VEHICLE             NaN            NaN
# 17       3479672  PASSENGER VEHICLE             NaN            NaN
# 23       4026252              Sedan             NaN            NaN
# 31       3953333              Sedan             NaN            NaN
# 42       4307654              Sedan           Sedan            NaN
#
#    VEHICLE_TYPE_4 VEHICLE_TYPE_5
# 10            NaN            NaN
# 17            NaN            NaN
# 23            NaN            NaN
# 31            NaN            NaN
# 42            NaN            NaN
#
# [5 rows x 28 columns]

# %%
lowercase = lambda x: str(x).lower()
data.rename(lowercase, axis='columns')
# Out:
#    crash_date_crash_time    borough  zip_code   latitude  longitude  \
# 10   2014-02-03 20:30:00        NaN       NaN  40.734926 -73.923111
# 17   2016-06-12 00:00:00  MANHATTAN   10027.0  40.807770 -73.945490
# 23   2018-08-01 05:15:00        NaN       NaN  40.895195 -73.880120
# 31   2018-07-31 13:12:00        NaN       NaN  40.833736 -73.888810
# 42   2020-04-04 22:52:00   BROOKLYN   11207.0  40.669190 -73.885700
# 45   2020-04-03 17:45:00        NaN       NaN  40.732830 -73.974150
# 49   2018-07-31 07:25:00      BRONX   10456.0  40.830048 -73.906320
# 51   2018-07-30 11:00:00        NaN       NaN  40.792263 -73.793320
# 57   2014-01-31 14:10:00        NaN       NaN  40.826454 -73.855328
# 60   2018-07-30 21:14:00        NaN       NaN  40.736732 -73.854510
# 73   2020-03-27 00:00:00        NaN       NaN  40.875122 -73.905174
# 78   2020-03-27 19:15:00     QUEENS   11419.0  40.693604 -73.822900
# 82   2020-03-27 09:55:00        NaN       NaN  40.809563 -73.929230
# 85   2020-03-26 20:00:00     QUEENS   11428.0  40.728207 -73.738170
# 91   2018-07-28 16:30:00     QUEENS   11385.0  40.705135 -73.902930
# 95   2016-06-09 22:05:00   BROOKLYN   11224.0  40.580376 -73.983315
# 97   2018-07-28 22:20:00        NaN       NaN  40.786785 -73.809710
# 98   2016-06-09 07:15:00        NaN       NaN  40.770060 -73.906790
#
#                           location                    on_street_name  \
# 10  POINT (-73.9231109 40.7349257)                               NaN
# 17      POINT (-73.94549 40.80777)  WEST 125 STREET
# 23     POINT (-73.88012 40.895195)  JEROME AVENUE
# 31     POINT (-73.88881 40.833736)  HOE AVENUE
# 42       POINT (-73.8857 40.66919)  BLAKE AVENUE
# 45      POINT (-73.97415 40.73283)  FDR DRIVE
# 49     POINT (-73.90632 40.830048)                               NaN
# 51     POINT (-73.79332 40.792263)  THROGS NECK BRIDGE
# 57  POINT (-73.8553285 40.8264543)                               NaN
# 60     POINT (-73.85451 40.736732)  LONG ISLAND EXPRESSWAY
# 73    POINT (-73.905174 40.875122)  MAJOR DEEGAN EXPRESSWAY
# 78      POINT (-73.8229 40.693604)                               NaN
# 82     POINT (-73.92923 40.809563)  EAST 135 STREET
# 85     POINT (-73.73817 40.728207)                               NaN
# 91     POINT (-73.90293 40.705135)                               NaN
# 95    POINT (-73.983315 40.580376)                               NaN
# 97     POINT (-73.80971 40.786785)  CROSS ISLAND PARKWAY
# 98      POINT (-73.90679 40.77006)  42 STREET
#
#    cross_street_name                           off_street_name  \
# 10               NaN                                       NaN
# 17      LENOX AVENUE                                       NaN
# 23               NaN                                       NaN
# 31               NaN                                       NaN
# 42     JEROME STREET                                       NaN
# 45               NaN                                       NaN
# 49               NaN  3475      3 AVENUE
# 51               NaN                                       NaN
# 57               NaN                                       NaN
# 60               NaN                                       NaN
# 73               NaN                                       NaN
# 78               NaN  124-05    95 AVENUE
# 82          3 AVENUE                                       NaN
# 85               NaN  90-42     BORKEL PLACE
# 91               NaN  2012      MADISON STREET
# 95               NaN  2757      WEST 15 STREET
# 97               NaN                                       NaN
# 98               NaN                                       NaN
#
#     injured_persons  ...  contributing_factor_vehicle_2  \
# 10                0  ...                            NaN
# 17                1  ...                            NaN
# 23                1  ...                            NaN
# 31                0  ...                            NaN
# 42                0  ...                    Unspecified
# 45                1  ...                            NaN
# 49                0  ...                            NaN
# 51                0  ...                            NaN
# 57                0  ...                    Unspecified
# 60                0  ...                    Unspecified
# 73                0  ...                            NaN
# 78                0  ...                            NaN
# 82                0  ...                    Unspecified
# 85                0  ...                            NaN
# 91                0  ...                            NaN
# 95                0  ...                            NaN
# 97                1  ...                            NaN
# 98                0  ...                            NaN
#
#     contributing_factor_vehicle_3  contributing_factor_vehicle_4  \
# 10                            NaN                            NaN
# 17                            NaN                            NaN
# 23                            NaN                            NaN
# 31                            NaN                            NaN
# 42                            NaN                            NaN
# 45                            NaN                            NaN
# 49                            NaN                            NaN
# 51                            NaN                            NaN
# 57                            NaN                            NaN
# 60                    Unspecified                            NaN
# 73                            NaN                            NaN
# 78                            NaN                            NaN
# 82                            NaN                            NaN
# 85                            NaN                            NaN
# 91                            NaN                            NaN
# 95                            NaN                            NaN
# 97                            NaN                            NaN
# 98                            NaN                            NaN
#
#     contributing_factor_vehicle_5  collision_id     vehicle_type_1  \
# 10                            NaN       3046267  PASSENGER VEHICLE
# 17                            NaN       3479672  PASSENGER VEHICLE
# 23                            NaN       4026252              Sedan
# 31                            NaN       3953333              Sedan
# 42                            NaN       4307654              Sedan
# 45                            NaN       4307474              Sedan
# 49                            NaN       3952146              Sedan
# 51                            NaN       3952522              Sedan
# 57                            NaN       2889433                VAN
# 60                            NaN       3951337               Taxi
# 73                            NaN       4304452              Sedan
# 78                            NaN       4304485              Sedan
# 82                            NaN       4304512              Sedan
# 85                            NaN       4304245              Sedan
# 91                            NaN       3950616              Sedan
# 95                            NaN       3460473  PASSENGER VEHICLE
# 97                            NaN       3949913         Motorcycle
# 98                            NaN       3459634  PASSENGER VEHICLE
#
#        vehicle_type_2 vehicle_type_3 vehicle_type_4 vehicle_type_5
# 10                NaN            NaN            NaN            NaN
# 17                NaN            NaN            NaN            NaN
# 23                NaN            NaN            NaN            NaN
# 31                NaN            NaN            NaN            NaN
# 42              Sedan            NaN            NaN            NaN
# 45                NaN            NaN            NaN            NaN
# 49                NaN            NaN            NaN            NaN
# 51                NaN            NaN            NaN            NaN
# 57  PASSENGER VEHICLE            NaN            NaN            NaN
# 60               Taxi           Taxi            NaN            NaN
# 73                NaN            NaN            NaN            NaN
# 78                NaN            NaN            NaN            NaN
# 82              Sedan            NaN            NaN            NaN
# 85                NaN            NaN            NaN            NaN
# 91                NaN            NaN            NaN            NaN
# 95  PASSENGER VEHICLE            NaN            NaN            NaN
# 97                NaN            NaN            NaN            NaN
# 98  PASSENGER VEHICLE            NaN            NaN            NaN
#
# [18 rows x 28 columns]
